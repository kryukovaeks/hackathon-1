# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
import help_function

# %%
df = pd.read_csv('data/train_data.csv', index_col=0,parse_dates=True)


df.plot()
# Out:
# <AxesSubplot:xlabel='time'>

# %%
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(df['price'], lags = 10)
# Out:
# /opt/anaconda3/envs/pythonProject3/lib/python3.9/site-packages/statsmodels/compat/pandas.py:61: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import Int64Index as NumericIndex

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(df['price'], lags = 10, method = "ols")

# %%
X_train = df['price']
from statsmodels.tsa.ar_model import AutoReg
ar_model = AutoReg(X_train, lags = 1).fit()

ar_model.summary()

# %%
ar_model = AutoReg(X_train, lags = 2).fit()

ar_model.summary()

# %%
ma_model = ARMA(X_train, order = (0, 1)).fit()

ma_model.summary()

# %%
from statsmodels.tsa.arima_model import ARMA
ma_model = ARMA(X_train, order = (0, 2)).fit()

ma_model.summary()
