# %%
#look at corr between diff periods - arima
#lasso logic reg
#arima
#reg
#

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
import help_function
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('data/train_data.csv', index_col=0,parse_dates=True)

# %%
required_rows = 14*24*60
df_train = df [-required_rows:]
df_train.tail()
# Out:
#                         price     volume
# time
# 2021-12-31 23:55:00  16832.76  39.870865
# 2021-12-31 23:56:00  16828.93  13.840201
# 2021-12-31 23:57:00  16817.76  22.845215
# 2021-12-31 23:58:00  16796.24  85.997617
# 2021-12-31 23:59:00  16804.84  37.329398

# %%
data = df_train.to_numpy()
x_train, y_train, x_test, y_test = help_function.prepare_data(data,scaler = 'std',type_ml = 'reg')

print(x_train.shape)
print(y_train.shape)
# Out:
# (3216, 60, 2)
# (3216, 1)

# %%
print(x_test.shape)
# Out:
# (804, 60, 2)

# %%
from tensorflow.keras.layers import LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Reshape
from tensorflow.keras.layers import Conv1D, Lambda, Flatten
input_shape = x_train[0].shape
def build_lstm_model(input_shape):
    model = Sequential()
    model.add(Reshape(input_shape, input_shape=input_shape))

    model.add(LSTM(units=50, return_sequences=True,))
    model.add(LSTM(units=50, return_sequences=False))
    model.add(Dense(units=25))
    model.add(Dense(units=2))

    return(model)

model = help_function.train_plot_model(x_train, y_train, x_test, y_test,
    build_lstm_model(input_shape),
                     type_ml ='reg')
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  reshape_11 (Reshape)        (None, 60, 2)             0
#
#  lstm_22 (LSTM)              (None, 60, 50)            10600
#
#  lstm_23 (LSTM)              (None, 50)                20200
#
#  dense_22 (Dense)            (None, 25)                1275
#
#  dense_23 (Dense)            (None, 2)                 52
#
# ...
# Total params: 32,127
# Trainable params: 32,127
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/20
# 81/81 [==============================] - 10s 59ms/step - loss: 486.6917 - val_loss: 607.7926
# Epoch 2/20
# 81/81 [==============================] - 3s 38ms/step - loss: 474.1636 - val_loss: 595.4893
# Epoch 3/20
# 81/81 [==============================] - 3s 43ms/step - loss: 473.6117 - val_loss: 603.4335
# Epoch 4/20
# ...

# %%
model.save("models/two_weeks_lstm_reg.h5")
